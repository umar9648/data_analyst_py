# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graphs_object as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 import plotly.graphs_object as go
#
# ModuleNotFoundError: No module named 'plotly.graphs_object'

# %%
df=pd.read_csv(r"C:\Users\Umar\Downloads\Dataset - Dataset.csv")

# %%
df.columns
# Out:
# Index(['Restaurant ID', ' Restaurant Name ', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.head()
# Out:
#    Restaurant ID          Restaurant Name   Country Code              City  \
# 0      6317637.0         Le Petit Souffle          162.0       Makati City
# 1      6304287.0         Izakaya Kikufuji          162.0       Makati City
# 2      6300002.0   Heat - Edsa Shangri-La          162.0  Mandaluyong City
# 3      6318506.0                     Ooma          162.0  Mandaluyong City
# 4      6314302.0              Sambo Kojin          162.0  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# # Distribution of Ratings: Identify the overall distribution of restaurant ratings in the dataset.

# %%
#visualize the distribution of rating
sns.histplot(df['Aggregate rating'], bins=30, kde=True)
plt.title("Distribution of Ratings")
plt.show()

# %% [markdown]
# As we can see that in above chart that Aggregate rating is 3.5

# %% [markdown]
# # Distribution of Costs: Understand the distribution of average costs for two people across all restaurants.

# %%
#visualizing the distribution of costs for two people 
sns.histplot(df['Average Cost for two'].head(), bins=30, kde=True)
plt.title("Average Cost for two")
plt.show()

# %%
city_count=df['City']
count=city_count.values
label=city_count.index()
fig=go.Figure(df[go.Pie(labels=label, values=count)])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 city_count=df['City']
#       2 count=city_count.values
# ----> 3 label=city_count.index()
#       4 fig=go.Figure(df[go.Pie(labels=label, values=count)])
#       5 fig.show()
#
# TypeError: 'RangeIndex' object is not callable

# %%
#countplot for the number of restaurant in each city.

sns.countplot(x='City', data=df, order=df['City'].value_counts().index)
plt.xticks(rotation=45, ha='right')
plt.title('Restaurant in each city')
plt.show()

# %% [markdown]
# # City-wise Cost Differences: Investigate how the average cost for two people varies across different cities.

# %%
#boxplot to investigate how the average cost for two peope varies across different cities.
sns.boxplot(x='City', y='Average Cost for two', data=df.head(20))
plt.xticks(rotation=45, ha='right')
plt.title(' Average cost for two people varies across different cities')
plt.show()

# %% [markdown]
# # Relationships between Numerical Columns: Examine potential relationships between average cost, rating, and votes using the pairplot.

# %%
# Pairplot for numerical columns
sns.pairplot(df[['Average Cost for two', 'Aggregate rating', 'Votes']].head(20))
plt.suptitle('Pairplot of Numerical Columns', y=1.02)
plt.show()
# Out:
# C:\Users\Umar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Recommendations:
# Focus on High-Rated Cuisines: Consider promoting and expanding offerings in cuisines that receive higher ratings to attract more customers.
#
# City-specific Marketing Strategies: Tailor marketing strategies based on the average cost and popular cuisines in each city to better cater to local preferences.
#
# Online Presence Enhancement: Encourage more restaurants to adopt online delivery services and promote the convenience of table booking options to attract a wider customer base.
#
# Quality vs. Cost Analysis: Investigate whether there is a significant correlation between higher average costs and better ratings. Assess if customers perceive higher costs as indicative of better quality.
#
# Explore Customer Preferences: Conduct surveys or analyze customer reviews to understand specific preferences and areas for improvement in different cities and cuisines.
